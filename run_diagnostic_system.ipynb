# %%
# Cell 1: Run the entire training pipeline
# %run app.py

# # Cell 2: After training, test on a specific image
# from app import predict_sample, VGG16_model, ml_classifiers, VGG16_base_model

# # Replace with your image path
# test_image = "C-NMC_Leukemia/training_data/all/sample_image.jpg"
# results = predict_sample(test_image, VGG16_model, ml_classifiers, VGG16_base_model)

# Cell 3: View diagnostic logs
import pandas as pd
logs = pd.read_csv('logs/diagnostic_log.csv')
print(logs.tail(10))
# Out:
# Number of training samples: 7462
# Number of test samples: 1600
# Number of validation samples: 1599
# Found 7462 validated image filenames belonging to 2 classes.
# Found 1599 validated image filenames belonging to 2 classes.
# Found 1600 validated image filenames belonging to 2 classes.
#
# ============================================================
# EXTRACTING FEATURES FROM VGG16
# ============================================================
#
# Extracting training features...
#   → Processed 7462 samples
# Extracting validation features...
#   → Processed 1599 samples
# Extracting test features...
#   → Processed 1600 samples
#
# Feature extraction complete!
# Training features shape: (7462, 512)
# Validation features shape: (1599, 512)
# Test features shape: (1600, 512)
#
# ============================================================
# TRAINING HYBRID ML CLASSIFIERS
# ============================================================
#
# Training SVM Classifier...
# Training Random Forest Classifier...
#
# ============================================================
# CLASSIFIER COMPARISON
# ============================================================
#         Model  Train Accuracy  Validation Accuracy  Test Accuracy
#           SVM        0.826990             0.828643       0.809375
# Random Forest        0.993701             0.828018       0.810000
# ============================================================
# ============================================================
# TRAINING VGG16 END-TO-END MODEL
# ============================================================
# Epoch 1/50
# 187/187 [==============================] - 44s 193ms/step - loss: 6.0158 - accuracy: 0.6612 - val_loss: 2.6357 - val_accuracy: 0.7724
# Epoch 2/50
# 187/187 [==============================] - 31s 164ms/step - loss: 3.9454 - accuracy: 0.7167 - val_loss: 2.0398 - val_accuracy: 0.7836
# Epoch 3/50
# 187/187 [==============================] - 30s 161ms/step - loss: 2.9421 - accuracy: 0.7221 - val_loss: 1.5994 - val_accuracy: 0.7992
# Epoch 4/50
# 187/187 [==============================] - 29s 156ms/step - loss: 2.1009 - accuracy: 0.7333 - val_loss: 1.1466 - val_accuracy: 0.7949
# Epoch 5/50
# 187/187 [==============================] - 29s 156ms/step - loss: 1.5570 - accuracy: 0.7376 - val_loss: 0.8311 - val_accuracy: 0.7730
# Epoch 6/50
# 187/187 [==============================] - 29s 156ms/step - loss: 1.1438 - accuracy: 0.7439 - val_loss: 0.6960 - val_accuracy: 0.7955
# Epoch 7/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.8888 - accuracy: 0.7522 - val_loss: 0.6396 - val_accuracy: 0.8130
# Epoch 8/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.7413 - accuracy: 0.7619 - val_loss: 0.5600 - val_accuracy: 0.7874
# Epoch 9/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.6543 - accuracy: 0.7612 - val_loss: 0.5306 - val_accuracy: 0.7949
# Epoch 10/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.6118 - accuracy: 0.7664 - val_loss: 0.5315 - val_accuracy: 0.7736
# Epoch 11/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.5808 - accuracy: 0.7706 - val_loss: 0.5122 - val_accuracy: 0.8080
# Epoch 12/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.5672 - accuracy: 0.7706 - val_loss: 0.5100 - val_accuracy: 0.7861
# Epoch 13/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.5436 - accuracy: 0.7767 - val_loss: 0.4868 - val_accuracy: 0.8049
# Epoch 14/50
# 187/187 [==============================] - 29s 157ms/step - loss: 0.5133 - accuracy: 0.7873 - val_loss: 0.4743 - val_accuracy: 0.8036
# Epoch 15/50
# 187/187 [==============================] - 29s 155ms/step - loss: 0.4995 - accuracy: 0.7884 - val_loss: 0.5055 - val_accuracy: 0.8124
# Epoch 16/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4971 - accuracy: 0.7891 - val_loss: 0.4747 - val_accuracy: 0.8149
# Epoch 17/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.4898 - accuracy: 0.7935 - val_loss: 0.4724 - val_accuracy: 0.8218
# Epoch 18/50
# 187/187 [==============================] - 30s 159ms/step - loss: 0.4884 - accuracy: 0.7895 - val_loss: 0.4702 - val_accuracy: 0.8080
# Epoch 19/50
# 187/187 [==============================] - 29s 157ms/step - loss: 0.4964 - accuracy: 0.7907 - val_loss: 0.4645 - val_accuracy: 0.8011
# Epoch 20/50
# 187/187 [==============================] - 29s 157ms/step - loss: 0.5041 - accuracy: 0.7822 - val_loss: 0.4669 - val_accuracy: 0.8180
# Epoch 21/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4765 - accuracy: 0.7958 - val_loss: 0.4475 - val_accuracy: 0.8136
# Epoch 22/50
# 187/187 [==============================] - 30s 158ms/step - loss: 0.4873 - accuracy: 0.7861 - val_loss: 0.5145 - val_accuracy: 0.8218
# Epoch 23/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4822 - accuracy: 0.7903 - val_loss: 0.4527 - val_accuracy: 0.8155
# Epoch 24/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4950 - accuracy: 0.7814 - val_loss: 0.5055 - val_accuracy: 0.8049
# Epoch 25/50
# 187/187 [==============================] - 30s 159ms/step - loss: 0.4800 - accuracy: 0.7962 - val_loss: 0.4473 - val_accuracy: 0.8105
# Epoch 26/50
# 187/187 [==============================] - 30s 161ms/step - loss: 0.4843 - accuracy: 0.7931 - val_loss: 0.4417 - val_accuracy: 0.8205
# Epoch 27/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4694 - accuracy: 0.7979 - val_loss: 0.4936 - val_accuracy: 0.8118
# Epoch 28/50
# 187/187 [==============================] - 29s 155ms/step - loss: 0.4866 - accuracy: 0.7960 - val_loss: 0.4579 - val_accuracy: 0.8230
# Epoch 29/50
# 187/187 [==============================] - 29s 155ms/step - loss: 0.4734 - accuracy: 0.7955 - val_loss: 0.4528 - val_accuracy: 0.8230
# Epoch 30/50
# 187/187 [==============================] - 29s 155ms/step - loss: 0.4790 - accuracy: 0.7924 - val_loss: 0.4901 - val_accuracy: 0.8180
# Epoch 31/50
# 187/187 [==============================] - 29s 157ms/step - loss: 0.4824 - accuracy: 0.7930 - val_loss: 0.5320 - val_accuracy: 0.8068
# ============================================================
# VGG16 END-TO-END MODEL EVALUATION
# ============================================================
#              Loss       Accuracy
# ----------------------------------
# Train        0.43431    0.80500
# Validation   0.44169    0.82051
# Test         0.47969    0.79562
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 41 batches). You may need to use the repeat() function when building your dataset.
# ============================================================
# GRAD-CAM EXPLAINABILITY VISUALIZATION
# ============================================================
#
# Analyzing: UID_78_29_7_all.bmp (True Label: all)
# C:\Users\Lenovo\Desktop\major\final\code\app.py:279: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   jet = plt.cm.get_cmap("jet")
# Analyzing: UID_24_8_3_all.bmp (True Label: all)
# Analyzing: UID_50_9_6_all.bmp (True Label: all)
# ============================================================
# PREDICTION ON UNKNOWN SAMPLE
# ============================================================
#
# ============================================================
# DIAGNOSTIC REPORT: UID_48_9_5_all.bmp
# ============================================================
#                 Model Prediction Confidence
# VGG16 (Deep Learning)        ALL     0.5473
#                   SVM        ALL     0.8478
#         Random Forest        ALL     0.6496
# ============================================================
#
#
# [LOG] Prediction logged to diagnostic_log.csv
# Generating Grad-CAM visualization...
# C:\Users\Lenovo\Desktop\major\final\code\app.py:279: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   jet = plt.cm.get_cmap("jet")
# ============================================================
# DIAGNOSTIC SYSTEM READY
# ============================================================
# ✓ Feature extraction: VGG16
# ✓ Classifiers trained: SVM, Random Forest
# ✓ Explainability: Grad-CAM implemented
# ✓ Logging system: Active
# ✓ Results logged to: logs/diagnostic_log.csv
# ============================================================
#
# 💡 Call: plot_model_comparison(ml_results, vgg16_test_acc) to compare all 3 models
#              Timestamp                                         Image_Path  \
# 0  2026-05-07 14:14:28  C-NMC_Leukemia\training_data\hem\UID_H40_1_5_h...
# 1  2026-05-07 14:39:47  C-NMC_Leukemia\training_data\all\UID_32_13_6_a...
# 2  2026-05-07 15:12:02  C-NMC_Leukemia\training_data\all\UID_74_3_1_al...
# 3  2026-05-07 15:49:06  C-NMC_Leukemia\training_data\all\UID_51_34_3_a...
# 4  2026-05-07 16:18:39  C-NMC_Leukemia\training_data\hem\UID_H2_41_2_h...
# 5  2026-05-08 09:12:43  C-NMC_Leukemia\training_data\all\UID_48_9_5_al...
#
#   Diagnosis  Confidence  Model
# 0       ALL      0.5666  VGG16
# 1       ALL      0.9393  VGG16
# 2       ALL      0.9732  VGG16
# 3       ALL      0.9668  VGG16
# 4       ALL      0.7812  VGG16
# 5       ALL      0.5473  VGG16

# %%
plot_model_comparison(ml_results, vgg16_test_acc)
# Out:
# ✅ Model comparison chart saved as: model_comparison.png
